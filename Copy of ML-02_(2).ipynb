# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
train = '/content/drive/MyDrive/Capstone Project/ML Colab/Dataset/Fix/train'
test = '/content/drive/MyDrive/Capstone Project/ML Colab/Dataset/Fix/test'
validation = '/content/drive/MyDrive/Capstone Project/ML Colab/Dataset/Fix/val'

SIZE = 224
batch_size = 32

# %%
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    horizontal_flip = True,
    vertical_flip = True,
    rotation_range = 45, 
    zoom_range = 0.2,
    shear_range = 0.2,
    height_shift_range = 0.2,
    width_shift_range = 0.2,
    fill_mode = 'nearest'
)

validation_datagen = ImageDataGenerator(
    rescale = 1./255
)

test_datagen = ImageDataGenerator(
    rescale = 1./255
)

# %%
train_generator = train_datagen.flow_from_directory(
    train,
    target_size = (SIZE, SIZE),
    batch_size = batch_size,
    class_mode = 'categorical',
    color_mode = 'rgb',
    shuffle = True,
    seed = 42
)

validation_generator = train_datagen.flow_from_directory(
    validation,
    target_size = (SIZE, SIZE),
    batch_size = batch_size,
    class_mode = 'categorical',
    color_mode = 'rgb',
    shuffle = True,
    seed = 42
)

test_generator = train_datagen.flow_from_directory(
    test,
    target_size = (SIZE, SIZE),
    batch_size = batch_size,
    class_mode = 'categorical',
    color_mode = 'rgb',
    shuffle = True,
    seed = 42
)
# Out:
# Found 704 images belonging to 8 classes.
# Found 88 images belonging to 8 classes.
# Found 88 images belonging to 8 classes.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(256, (3, 3), activation = 'relu', input_shape = (SIZE, SIZE, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.3),

    tf.keras.layers.Conv2D(256, (3, 3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.3),

    tf.keras.layers.Conv2D(128, (3, 3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.3),

    

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation = 'relu'),
    tf.keras.layers.Dense(8, activation = 'softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 256)     7168
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 256)    0
#  )
#
#  dropout (Dropout)           (None, 111, 111, 256)     0
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 256)     590080
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 256)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 54, 54, 256)       0
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       295040
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 26, 26, 128)       0
#
#  flatten (Flatten)           (None, 86528)             0
#
#  dense (Dense)               (None, 128)               11075712
#
#  dense_1 (Dense)             (None, 8)                 1032
#
# =================================================================
# Total params: 11,969,032
# Trainable params: 11,969,032
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'RMSprop',
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])

# %%
history = model.fit(
    train_generator,
    validation_data = validation_generator,
    epochs = 100,
    verbose = 2
)
# Out:
# Epoch 1/100
# 22/22 - 194s - loss: 9.0093 - accuracy: 0.1591 - val_loss: 1.9268 - val_accuracy: 0.2386 - 194s/epoch - 9s/step
# Epoch 2/100
# 22/22 - 24s - loss: 1.9785 - accuracy: 0.2585 - val_loss: 1.6333 - val_accuracy: 0.3864 - 24s/epoch - 1s/step
# Epoch 3/100
# 22/22 - 26s - loss: 1.6697 - accuracy: 0.3537 - val_loss: 1.5502 - val_accuracy: 0.3750 - 26s/epoch - 1s/step
# Epoch 4/100
# 22/22 - 23s - loss: 1.5836 - accuracy: 0.3764 - val_loss: 1.4404 - val_accuracy: 0.4091 - 23s/epoch - 1s/step
# Epoch 5/100
# 22/22 - 23s - loss: 1.5598 - accuracy: 0.4020 - val_loss: 1.3499 - val_accuracy: 0.4545 - 23s/epoch - 1s/step
# Epoch 6/100
# 22/22 - 24s - loss: 1.4762 - accuracy: 0.4474 - val_loss: 1.4016 - val_accuracy: 0.5455 - 24s/epoch - 1s/step
# Epoch 7/100
# 22/22 - 24s - loss: 1.3953 - accuracy: 0.4872 - val_loss: 1.2663 - val_accuracy: 0.4659 - 24s/epoch - 1s/step
# Epoch 8/100
# 22/22 - 25s - loss: 1.4085 - accuracy: 0.4517 - val_loss: 1.2196 - val_accuracy: 0.6023 - 25s/epoch - 1s/step
# Epoch 9/100
# 22/22 - 23s - loss: 1.3674 - accuracy: 0.5028 - val_loss: 1.2482 - val_accuracy: 0.5341 - 23s/epoch - 1s/step
# Epoch 10/100
# 22/22 - 22s - loss: 1.3232 - accuracy: 0.5071 - val_loss: 1.1132 - val_accuracy: 0.6136 - 22s/epoch - 1s/step
# Epoch 11/100
# 22/22 - 23s - loss: 1.2553 - accuracy: 0.5312 - val_loss: 1.1765 - val_accuracy: 0.6023 - 23s/epoch - 1s/step
# Epoch 12/100
# 22/22 - 23s - loss: 1.2450 - accuracy: 0.5469 - val_loss: 1.2594 - val_accuracy: 0.5227 - 23s/epoch - 1s/step
# Epoch 13/100
# 22/22 - 23s - loss: 1.2191 - accuracy: 0.5767 - val_loss: 1.0263 - val_accuracy: 0.6250 - 23s/epoch - 1s/step
# Epoch 14/100
# 22/22 - 23s - loss: 1.1878 - accuracy: 0.5668 - val_loss: 1.1340 - val_accuracy: 0.5682 - 23s/epoch - 1s/step
# Epoch 15/100
# 22/22 - 23s - loss: 1.1961 - accuracy: 0.5554 - val_loss: 1.2205 - val_accuracy: 0.5455 - 23s/epoch - 1s/step
# Epoch 16/100
# 22/22 - 22s - loss: 1.1404 - accuracy: 0.5781 - val_loss: 1.0266 - val_accuracy: 0.6705 - 22s/epoch - 1s/step
# Epoch 17/100
# 22/22 - 23s - loss: 1.1704 - accuracy: 0.5739 - val_loss: 1.0189 - val_accuracy: 0.5795 - 23s/epoch - 1s/step
# Epoch 18/100
# 22/22 - 23s - loss: 1.1145 - accuracy: 0.5881 - val_loss: 0.9630 - val_accuracy: 0.6477 - 23s/epoch - 1s/step
# Epoch 19/100
# 22/22 - 23s - loss: 1.1115 - accuracy: 0.6094 - val_loss: 1.0615 - val_accuracy: 0.6250 - 23s/epoch - 1s/step
# Epoch 20/100
# 22/22 - 22s - loss: 1.1006 - accuracy: 0.6236 - val_loss: 0.8821 - val_accuracy: 0.6818 - 22s/epoch - 997ms/step
# Epoch 21/100
# 22/22 - 23s - loss: 1.0440 - accuracy: 0.6335 - val_loss: 0.9336 - val_accuracy: 0.6705 - 23s/epoch - 1s/step
# Epoch 22/100
# 22/22 - 25s - loss: 1.0652 - accuracy: 0.6236 - val_loss: 0.9531 - val_accuracy: 0.6364 - 25s/epoch - 1s/step
# Epoch 23/100
# 22/22 - 24s - loss: 0.9252 - accuracy: 0.6747 - val_loss: 0.8607 - val_accuracy: 0.7500 - 24s/epoch - 1s/step
# Epoch 24/100
# 22/22 - 23s - loss: 1.1081 - accuracy: 0.6307 - val_loss: 0.8920 - val_accuracy: 0.6818 - 23s/epoch - 1s/step
# Epoch 25/100
# 22/22 - 24s - loss: 0.8698 - accuracy: 0.6889 - val_loss: 1.0476 - val_accuracy: 0.5909 - 24s/epoch - 1s/step
# Epoch 26/100
# 22/22 - 23s - loss: 0.9533 - accuracy: 0.6619 - val_loss: 0.8105 - val_accuracy: 0.7159 - 23s/epoch - 1s/step
# Epoch 27/100
# 22/22 - 23s - loss: 0.8876 - accuracy: 0.6875 - val_loss: 0.7412 - val_accuracy: 0.7500 - 23s/epoch - 1s/step
# Epoch 28/100
# 22/22 - 23s - loss: 0.8530 - accuracy: 0.6861 - val_loss: 0.7643 - val_accuracy: 0.6932 - 23s/epoch - 1s/step
# Epoch 29/100
# 22/22 - 23s - loss: 0.9734 - accuracy: 0.6591 - val_loss: 0.7336 - val_accuracy: 0.7386 - 23s/epoch - 1s/step
# Epoch 30/100
# 22/22 - 22s - loss: 0.8061 - accuracy: 0.7273 - val_loss: 1.0910 - val_accuracy: 0.6364 - 22s/epoch - 1s/step
# Epoch 31/100
# 22/22 - 23s - loss: 0.8606 - accuracy: 0.6932 - val_loss: 0.6442 - val_accuracy: 0.8295 - 23s/epoch - 1s/step
# Epoch 32/100
# 22/22 - 23s - loss: 0.7787 - accuracy: 0.7287 - val_loss: 0.7083 - val_accuracy: 0.7614 - 23s/epoch - 1s/step
# Epoch 33/100
# 22/22 - 23s - loss: 0.8825 - accuracy: 0.7017 - val_loss: 0.6950 - val_accuracy: 0.7273 - 23s/epoch - 1s/step
# Epoch 34/100
# 22/22 - 23s - loss: 0.6717 - accuracy: 0.7656 - val_loss: 1.2408 - val_accuracy: 0.6250 - 23s/epoch - 1s/step
# Epoch 35/100
# 22/22 - 22s - loss: 0.8651 - accuracy: 0.7060 - val_loss: 0.8843 - val_accuracy: 0.7386 - 22s/epoch - 1s/step
# Epoch 36/100
# 22/22 - 23s - loss: 0.6401 - accuracy: 0.7585 - val_loss: 0.7105 - val_accuracy: 0.6932 - 23s/epoch - 1s/step
# Epoch 37/100
# 22/22 - 22s - loss: 0.9510 - accuracy: 0.6903 - val_loss: 0.9047 - val_accuracy: 0.6364 - 22s/epoch - 1s/step
# Epoch 38/100
# 22/22 - 23s - loss: 0.7145 - accuracy: 0.7500 - val_loss: 0.5836 - val_accuracy: 0.7727 - 23s/epoch - 1s/step
# Epoch 39/100
# 22/22 - 23s - loss: 0.6967 - accuracy: 0.7500 - val_loss: 0.4759 - val_accuracy: 0.8409 - 23s/epoch - 1s/step
# Epoch 40/100
# 22/22 - 22s - loss: 0.6232 - accuracy: 0.7727 - val_loss: 0.5681 - val_accuracy: 0.7955 - 22s/epoch - 1s/step
# Epoch 41/100
# 22/22 - 22s - loss: 0.6272 - accuracy: 0.7812 - val_loss: 0.5012 - val_accuracy: 0.8523 - 22s/epoch - 1s/step
# Epoch 42/100
# 22/22 - 22s - loss: 0.6117 - accuracy: 0.7841 - val_loss: 0.6157 - val_accuracy: 0.7841 - 22s/epoch - 1s/step
# Epoch 43/100
# 22/22 - 23s - loss: 0.6228 - accuracy: 0.7926 - val_loss: 0.5133 - val_accuracy: 0.8068 - 23s/epoch - 1s/step
# Epoch 44/100
# 22/22 - 22s - loss: 0.7201 - accuracy: 0.7599 - val_loss: 0.5615 - val_accuracy: 0.7955 - 22s/epoch - 984ms/step
# Epoch 45/100
# 22/22 - 23s - loss: 0.5873 - accuracy: 0.7841 - val_loss: 0.5920 - val_accuracy: 0.7955 - 23s/epoch - 1s/step
# Epoch 46/100
# 22/22 - 23s - loss: 0.5103 - accuracy: 0.8182 - val_loss: 0.5573 - val_accuracy: 0.8295 - 23s/epoch - 1s/step
# Epoch 47/100
# 22/22 - 22s - loss: 0.5882 - accuracy: 0.7940 - val_loss: 0.6940 - val_accuracy: 0.7841 - 22s/epoch - 988ms/step
# Epoch 48/100
# 22/22 - 23s - loss: 0.5318 - accuracy: 0.8153 - val_loss: 0.7435 - val_accuracy: 0.7841 - 23s/epoch - 1s/step
# Epoch 49/100
# 22/22 - 23s - loss: 0.6201 - accuracy: 0.8111 - val_loss: 0.6416 - val_accuracy: 0.7614 - 23s/epoch - 1s/step
# Epoch 50/100
# 22/22 - 23s - loss: 0.6203 - accuracy: 0.8026 - val_loss: 0.3430 - val_accuracy: 0.8636 - 23s/epoch - 1s/step
# Epoch 51/100
# 22/22 - 23s - loss: 0.5699 - accuracy: 0.8068 - val_loss: 0.4874 - val_accuracy: 0.7955 - 23s/epoch - 1s/step
# Epoch 52/100
# 22/22 - 22s - loss: 0.6105 - accuracy: 0.8011 - val_loss: 0.5743 - val_accuracy: 0.8068 - 22s/epoch - 1s/step
# Epoch 53/100
# 22/22 - 23s - loss: 0.4614 - accuracy: 0.8366 - val_loss: 0.6926 - val_accuracy: 0.7727 - 23s/epoch - 1s/step
# Epoch 54/100
# 22/22 - 22s - loss: 0.4668 - accuracy: 0.8580 - val_loss: 0.4100 - val_accuracy: 0.8750 - 22s/epoch - 985ms/step
# Epoch 55/100
# 22/22 - 22s - loss: 0.7032 - accuracy: 0.7841 - val_loss: 0.3588 - val_accuracy: 0.8977 - 22s/epoch - 1s/step
# Epoch 56/100
# 22/22 - 22s - loss: 0.5596 - accuracy: 0.8438 - val_loss: 0.3817 - val_accuracy: 0.8523 - 22s/epoch - 1s/step
# Epoch 57/100
# 22/22 - 23s - loss: 0.4313 - accuracy: 0.8480 - val_loss: 1.2394 - val_accuracy: 0.7045 - 23s/epoch - 1s/step
# Epoch 58/100
# 22/22 - 22s - loss: 0.4603 - accuracy: 0.8636 - val_loss: 0.3070 - val_accuracy: 0.8750 - 22s/epoch - 999ms/step
# Epoch 59/100
# 22/22 - 22s - loss: 0.4894 - accuracy: 0.8338 - val_loss: 0.3784 - val_accuracy: 0.8977 - 22s/epoch - 1s/step
# Epoch 60/100
# 22/22 - 22s - loss: 0.5180 - accuracy: 0.8366 - val_loss: 1.1788 - val_accuracy: 0.7159 - 22s/epoch - 987ms/step
# Epoch 61/100
# 22/22 - 23s - loss: 0.4830 - accuracy: 0.8793 - val_loss: 0.4139 - val_accuracy: 0.8409 - 23s/epoch - 1s/step
# Epoch 62/100
# 22/22 - 22s - loss: 0.3893 - accuracy: 0.8750 - val_loss: 1.3053 - val_accuracy: 0.7386 - 22s/epoch - 1s/step
# Epoch 63/100
# 22/22 - 23s - loss: 0.5083 - accuracy: 0.8210 - val_loss: 0.2185 - val_accuracy: 0.9091 - 23s/epoch - 1s/step
# Epoch 64/100
# 22/22 - 21s - loss: 0.5136 - accuracy: 0.8551 - val_loss: 0.2426 - val_accuracy: 0.9205 - 21s/epoch - 972ms/step
# Epoch 65/100
# 22/22 - 23s - loss: 0.3746 - accuracy: 0.8736 - val_loss: 0.2023 - val_accuracy: 0.9205 - 23s/epoch - 1s/step
# Epoch 66/100
# 22/22 - 25s - loss: 0.4627 - accuracy: 0.8608 - val_loss: 0.2614 - val_accuracy: 0.8864 - 25s/epoch - 1s/step
# Epoch 67/100
# 22/22 - 22s - loss: 0.3802 - accuracy: 0.8750 - val_loss: 0.3921 - val_accuracy: 0.8864 - 22s/epoch - 978ms/step
# Epoch 68/100
# 22/22 - 23s - loss: 0.3643 - accuracy: 0.8807 - val_loss: 0.1971 - val_accuracy: 0.9318 - 23s/epoch - 1s/step
# Epoch 69/100
# 22/22 - 25s - loss: 0.5005 - accuracy: 0.8494 - val_loss: 0.3775 - val_accuracy: 0.8523 - 25s/epoch - 1s/step
# Epoch 70/100
# 22/22 - 22s - loss: 0.5207 - accuracy: 0.8480 - val_loss: 0.2847 - val_accuracy: 0.8864 - 22s/epoch - 1s/step
# Epoch 71/100
# 22/22 - 22s - loss: 0.5609 - accuracy: 0.8551 - val_loss: 0.2985 - val_accuracy: 0.9091 - 22s/epoch - 1s/step
# Epoch 72/100
# 22/22 - 22s - loss: 0.2971 - accuracy: 0.8878 - val_loss: 0.3933 - val_accuracy: 0.8636 - 22s/epoch - 1s/step
# Epoch 73/100
# 22/22 - 22s - loss: 0.4527 - accuracy: 0.8594 - val_loss: 0.2503 - val_accuracy: 0.9091 - 22s/epoch - 981ms/step
# Epoch 74/100
# 22/22 - 23s - loss: 0.4322 - accuracy: 0.8693 - val_loss: 0.2588 - val_accuracy: 0.8864 - 23s/epoch - 1s/step
# Epoch 75/100
# 22/22 - 23s - loss: 0.5230 - accuracy: 0.8452 - val_loss: 0.4763 - val_accuracy: 0.8068 - 23s/epoch - 1s/step
# Epoch 76/100
# 22/22 - 22s - loss: 0.4414 - accuracy: 0.8665 - val_loss: 0.4902 - val_accuracy: 0.8182 - 22s/epoch - 989ms/step
# Epoch 77/100
# 22/22 - 23s - loss: 0.4425 - accuracy: 0.8736 - val_loss: 0.2742 - val_accuracy: 0.9091 - 23s/epoch - 1s/step
# Epoch 78/100
# 22/22 - 22s - loss: 0.3265 - accuracy: 0.8935 - val_loss: 0.7943 - val_accuracy: 0.7500 - 22s/epoch - 991ms/step
# Epoch 79/100
# 22/22 - 22s - loss: 0.4157 - accuracy: 0.8537 - val_loss: 0.2853 - val_accuracy: 0.8636 - 22s/epoch - 1s/step
# Epoch 80/100
# 22/22 - 23s - loss: 0.4557 - accuracy: 0.8807 - val_loss: 0.3361 - val_accuracy: 0.8750 - 23s/epoch - 1s/step
# Epoch 81/100
# 22/22 - 22s - loss: 0.3652 - accuracy: 0.8821 - val_loss: 0.1810 - val_accuracy: 0.9432 - 22s/epoch - 982ms/step
# Epoch 82/100
# 22/22 - 25s - loss: 0.4211 - accuracy: 0.8764 - val_loss: 0.2665 - val_accuracy: 0.8977 - 25s/epoch - 1s/step
# Epoch 83/100
# 22/22 - 22s - loss: 0.3150 - accuracy: 0.9062 - val_loss: 0.3405 - val_accuracy: 0.8864 - 22s/epoch - 990ms/step
# Epoch 84/100
# 22/22 - 23s - loss: 0.2886 - accuracy: 0.9062 - val_loss: 0.9873 - val_accuracy: 0.7614 - 23s/epoch - 1s/step
# Epoch 85/100
# 22/22 - 23s - loss: 0.5325 - accuracy: 0.8807 - val_loss: 0.2639 - val_accuracy: 0.8750 - 23s/epoch - 1s/step
# Epoch 86/100
# 22/22 - 22s - loss: 0.4140 - accuracy: 0.8750 - val_loss: 0.3015 - val_accuracy: 0.8977 - 22s/epoch - 1s/step
# Epoch 87/100
# 22/22 - 23s - loss: 0.3129 - accuracy: 0.8906 - val_loss: 0.3058 - val_accuracy: 0.8523 - 23s/epoch - 1s/step
# Epoch 88/100
# 22/22 - 25s - loss: 0.2464 - accuracy: 0.9162 - val_loss: 0.3491 - val_accuracy: 0.8409 - 25s/epoch - 1s/step
# Epoch 89/100
# 22/22 - 22s - loss: 0.4271 - accuracy: 0.8636 - val_loss: 0.3174 - val_accuracy: 0.8864 - 22s/epoch - 981ms/step
# Epoch 90/100
# 22/22 - 23s - loss: 0.3390 - accuracy: 0.8949 - val_loss: 0.5432 - val_accuracy: 0.8636 - 23s/epoch - 1s/step
# Epoch 91/100
# 22/22 - 22s - loss: 0.4858 - accuracy: 0.8821 - val_loss: 0.2285 - val_accuracy: 0.9318 - 22s/epoch - 981ms/step
# Epoch 92/100
# 22/22 - 23s - loss: 0.2583 - accuracy: 0.9162 - val_loss: 0.5819 - val_accuracy: 0.7727 - 23s/epoch - 1s/step
# Epoch 93/100
# 22/22 - 25s - loss: 0.3488 - accuracy: 0.8906 - val_loss: 0.2830 - val_accuracy: 0.9205 - 25s/epoch - 1s/step
# Epoch 94/100
# 22/22 - 22s - loss: 0.3853 - accuracy: 0.8935 - val_loss: 0.4012 - val_accuracy: 0.8864 - 22s/epoch - 983ms/step
# Epoch 95/100
# 22/22 - 23s - loss: 0.3338 - accuracy: 0.8935 - val_loss: 0.3324 - val_accuracy: 0.8864 - 23s/epoch - 1s/step
# Epoch 96/100
# 22/22 - 23s - loss: 0.3650 - accuracy: 0.9091 - val_loss: 0.5849 - val_accuracy: 0.8295 - 23s/epoch - 1s/step
# Epoch 97/100
# 22/22 - 22s - loss: 0.4226 - accuracy: 0.8679 - val_loss: 0.1397 - val_accuracy: 0.9545 - 22s/epoch - 995ms/step
# Epoch 98/100
# 22/22 - 23s - loss: 0.2568 - accuracy: 0.9176 - val_loss: 0.5006 - val_accuracy: 0.8182 - 23s/epoch - 1s/step
# Epoch 99/100
# 22/22 - 22s - loss: 0.5327 - accuracy: 0.8466 - val_loss: 0.1920 - val_accuracy: 0.9091 - 22s/epoch - 1s/step
# Epoch 100/100
# 22/22 - 22s - loss: 0.1836 - accuracy: 0.9460 - val_loss: 0.6330 - val_accuracy: 0.8636 - 22s/epoch - 1s/step

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(accuracy))

# Training and Validation Accuracy
plt.plot(epochs, accuracy, label = 'Training Accuracy')
plt.plot(epochs, val_accuracy, label = 'Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend(loc = 0)
plt.figure()

# Training and Validation Loss
plt.plot(epochs, loss, label = 'Training Loss')
plt.plot(epochs, val_loss, label = 'Validation Loss')
plt.title('Training and Validation Loss')
plt.legend(loc=0)
plt.figure()

plt.show()

# %%
model.evaluate(test_generator, verbose=2)
# Out:
# 3/3 - 16s - loss: 0.4334 - accuracy: 0.8295 - 16s/epoch - 5s/step
# [0.43343275785446167, 0.8295454382896423]

# %%
export_dir = '/content/drive/MyDrive/Capstone Project/ML Colab/Dataset/Fix/saved_model2'
tf.saved_model.save(model, export_dir)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.

# %%
converter = tf.lite.TFLiteConverter.from_saved_model(export_dir)
tflite_model = converter.convert()

# %%
import pathlib
tflite_model_file = pathlib.Path('/content/drive/MyDrive/Capstone Project/ML Colab/Dataset/Fix/saved_model2/ml.tflite')
tflite_model_file.write_bytes(tflite_model)
# Out:
# 47880232
